# %% [markdown]
# # Example script for importing variables into OpenSILEX.

# %%
import json
import os

from opensilex_python_client.auth import connect
from opensilex_python_client.file_management.read_yaml import read_yaml
from opensilex_python_client.variables import download_config_example, import_from_csv
from opensilex_python_client.variables.groups import manage

# %%
# 1. Authentication
with open('credentials.json') as f:
    credentials_dict = json.load(f)

client = connect.connect_to_opensilex(
    credentials_dict
)
# Out:
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ✓ Successful connection

# %% [markdown]
# ## Generate files to upload

# %%
# 2. File paths (modify these paths)
save_file_path = os.path.join(os.path.abspath(""), "output_files")
os.makedirs(save_file_path, exist_ok=True)
data_examples_variables_dir_path = os.path.realpath(os.path.join(os.path.abspath(""), "../data_examples/variables"))
os.makedirs(data_examples_variables_dir_path, exist_ok=True)
print(f"Config files: {data_examples_variables_dir_path}")

download_config_example.download_variables_config(data_examples_variables_dir_path)
# Out:
# Config files: /home/charleroy/GIT/GITLAB/opensilex_python_client/notebooks/data_examples/variables
# [07/21/26 15:47:14] 2026-07-21 15:47:14,766 — opensilex_python_client.variables.download_config_example — INFO —
#                     Copied test_variables.csv to
#                     /home/charleroy/GIT/GITLAB/opensilex_python_client/notebooks/data_examples/variables/test_varia
#                     bles.csv
#                     2026-07-21 15:47:14,774 — opensilex_python_client.variables.download_config_example — INFO —
#                     Copied test_config.yaml to
#                     /home/charleroy/GIT/GITLAB/opensilex_python_client/notebooks/data_examples/variables/test_confi
#                     g.yaml
#                     2026-07-21 15:47:14,779 — opensilex_python_client.variables.download_config_example — INFO —
#                     Copied test_variables_with_uris.csv to
#                     /home/charleroy/GIT/GITLAB/opensilex_python_client/notebooks/data_examples/variables/test_varia
#                     bles_with_uris.csv
#                     2026-07-21 15:47:14,786 — opensilex_python_client.variables.download_config_example — INFO —
#                     All 3 files saved to
#                     /home/charleroy/GIT/GITLAB/opensilex_python_client/notebooks/data_examples/variables

# %%
## 3. load files 


# without uris
# input_csv_path = os.path.realpath(os.path.join(os.path.abspath(""), "../data_examples/variables", "test_variables.csv"))
# with uris
input_csv_path = os.path.realpath(os.path.join(os.path.abspath(""), "../data_examples/variables", "test_variables_with_uris.csv"))

input_config_path = os.path.realpath(
    os.path.join(os.path.abspath(""), "../data_examples/variables", "test_config.yaml")
)
print(f"Input CSV path: {os.path.realpath(input_csv_path)}")
print(f"Input Config path: {os.path.realpath(input_config_path)}")
# Out:
# Input CSV path: /home/charleroy/GIT/GITLAB/opensilex_python_client/notebooks/data_examples/variables/test_variables_with_uris.csv
# Input Config path: /home/charleroy/GIT/GITLAB/opensilex_python_client/notebooks/data_examples/variables/test_config.yaml

# %%
# 3. Import variables (creates components + variables automatically)
grouped_vars = import_from_csv.run(client, input_csv_path, input_config_path, False)
# Out:
#                     2026-07-21 15:47:14,886 — opensilex_python_client.variables.import_variables_from_csv — INFO —
#                     Loading CSV and configuration:
#                     csv=/home/charleroy/GIT/GITLAB/opensilex_python_client/notebooks/data_examples/variables/test_v
#                     ariables_with_uris.csv,
#                     config=/home/charleroy/GIT/GITLAB/opensilex_python_client/notebooks/data_examples/variables/tes
#                     t_config.yaml
# Loading CSV and configuration...
#                     2026-07-21 15:47:14,893 — opensilex_python_client.variables.import_variables_from_csv — INFO —
#                     Loaded 2 rows from CSV
# Loaded 2 rows from CSV
#
# Resolving column mappings...
#                     2026-07-21 15:47:14,895 — opensilex_python_client.variables.import_variables_from_csv — INFO —
#                     Resolved column mappings: 16 columns mapped
#   Mapped 16 columns
#                     2026-07-21 15:47:14,898 — opensilex_python_client.variables.import_variables_from_csv — INFO —
#                     Starting component creation step
# ================================================================================
# STEP 1: CREATING COMPONENTS (AUTO-GENERATION FROM NAMES)
# ================================================================================
#                     2026-07-21 15:47:14,900 — opensilex_python_client.variables.ctx — DEBUG —
#                     get_entity(uri='test-variable:Plant')
# [07/21/26 15:47:15] 2026-07-21 15:47:15,023 — opensilex_python_client.variables.ctx — DEBUG —   response:
#                     {'metadata': {'pagination': {'pageSize': 0, 'currentPage': 0, 'totalCount': 0, 'totalPages': 0,
#                     'limitCount': 0, 'hasNextPage': False}, 'status': [], 'datafiles': []}, 'result':
#                     {'broad_match': [],
#                      'close_match': [],
#                      'description': 'Plant organism',
#                      'exact_match': [],
#                      'from_shared_resource_instance': None,
#                      'last_updated_date': None,
#                      'name': 'Plant',
#                      'narrow_match': [],
#                      'publication_date': datetime.datetime(2026, 7, 20, 13, 59, 31, 594784, tzinfo=tzutc()),
#                      'publisher': {'admin': True,
#                                    'email': 'guest@opensilex.org',
#                                    'enable': True,
#                                    'favorites': None,
#                                    'first_name': 'Guest',
#                                    'language': 'en',
#                                    'last_name': 'OpenSILEX',
#                                    'linked_person': 'opensilex-sandbox:id/user/guest.opensilex/Person',
#                                    'uri': 'opensilex-sandbox:id/user/guest.opensilex'},
#                      'uri': 'test-variable:Plant'}}
#                     2026-07-21 15:47:15,037 — opensilex_python_client.variables._component_resolver — INFO —
#                     Component Entity exists (by URI): test-variable:Plant
#                     2026-07-21 15:47:15,043 — opensilex_python_client.variables.ctx — DEBUG —
#                     search_characteristics(name='Height')
#                     2026-07-21 15:47:15,246 — opensilex_python_client.variables.ctx — DEBUG —   response:
#                     {'metadata': {'pagination': {'pageSize': 0, 'currentPage': 0, 'totalCount': 5, 'totalPages': 0,
#                     'limitCount': 0, 'hasNextPage': False}, 'status': [], 'datafiles': []}, 'result': [{'name':
#                     'height',
#                      'uri': 'http://phenome.inrae.fr/id/variable/characteristic.height'}, {'name': 'Height', 'uri':
#                     'http://purl.obolibrary.org/obo/PATO_0000119'}, {'name': 'HeightFlag',
#                      'uri': 'http://phenome.inrae.fr/id/variable/quality.heightflag'}, {'name': 'HeightStd',
#                      'uri': 'http://phenome.inrae.fr/id/variable/quality.heightstd'}, {'name': 'Mean plant height',
#                      'uri': 'http://phenome.inrae.fr/id/variable/characteristic.mean_plant_height'}]}
#                     2026-07-21 15:47:15,249 — opensilex_python_client.variables._component_resolver — INFO —
#                     Component Characteristic exists: Height
#                     2026-07-21 15:47:15,250 — opensilex_python_client.variables.ctx — DEBUG —
#                     search_methods(name='Manual')
#                     2026-07-21 15:47:15,465 — opensilex_python_client.variables.ctx — DEBUG —   response:
#                     {'metadata': {'pagination': {'pageSize': 0, 'currentPage': 0, 'totalCount': 1, 'totalPages': 0,
#                     'limitCount': 0, 'hasNextPage': False}, 'status': [], 'datafiles': []}, 'result': [{'name':
#                     'Manual', 'uri': 'http://phenome.inrae.fr/id/variable/method.manual'}]}
#                     2026-07-21 15:47:15,467 — opensilex_python_client.variables._component_resolver — INFO —
#                     Component Method exists: Manual
#                     2026-07-21 15:47:15,470 — opensilex_python_client.variables.ctx — DEBUG —
#                     search_units(name='Centimeter')
#                     2026-07-21 15:47:15,701 — opensilex_python_client.variables.ctx — DEBUG —   response:
#                     {'metadata': {'pagination': {'pageSize': 0, 'currentPage': 0, 'totalCount': 1, 'totalPages': 0,
#                     'limitCount': 0, 'hasNextPage': False}, 'status': [], 'datafiles': []}, 'result': [{'name':
#                     'Centimeter',
#                      'uri': 'http://opensilex.test/id/variable/unit.centimeter'}]}
#                     2026-07-21 15:47:15,704 — opensilex_python_client.variables._component_resolver — INFO —
#                     Component Unit exists: Centimeter
#                     2026-07-21 15:47:15,706 — opensilex_python_client.variables.ctx — DEBUG —
#                     get_entity(uri='test-variable:Plant')
#                     2026-07-21 15:47:15,828 — opensilex_python_client.variables.ctx — DEBUG —   response:
#                     {'metadata': {'pagination': {'pageSize': 0, 'currentPage': 0, 'totalCount': 0, 'totalPages': 0,
#                     'limitCount': 0, 'hasNextPage': False}, 'status': [], 'datafiles': []}, 'result':
#                     {'broad_match': [],
#                      'close_match': [],
#                      'description': 'Plant organism',
#                      'exact_match': [],
#                      'from_shared_resource_instance': None,
#                      'last_updated_date': None,
#                      'name': 'Plant',
#                      'narrow_match': [],
#                      'publication_date': datetime.datetime(2026, 7, 20, 13, 59, 31, 594784, tzinfo=tzutc()),
#                      'publisher': {'admin': True,
#                                    'email': 'guest@opensilex.org',
#                                    'enable': True,
#                                    'favorites': None,
#                                    'first_name': 'Guest',
#                                    'language': 'en',
#                                    'last_name': 'OpenSILEX',
#                                    'linked_person': 'opensilex-sandbox:id/user/guest.opensilex/Person',
#                                    'uri': 'opensilex-sandbox:id/user/guest.opensilex'},
#                      'uri': 'test-variable:Plant'}}
#                     2026-07-21 15:47:15,832 — opensilex_python_client.variables._component_resolver — INFO —
#                     Component Entity exists (by URI): test-variable:Plant
#                     2026-07-21 15:47:15,834 — opensilex_python_client.variables.ctx — DEBUG —
#                     search_characteristics(name='Biomass')
# [07/21/26 15:47:16] 2026-07-21 15:47:16,034 — opensilex_python_client.variables.ctx — DEBUG —   response:
#                     {'metadata': {'pagination': {'pageSize': 0, 'currentPage': 0, 'totalCount': 1, 'totalPages': 0,
#                     'limitCount': 0, 'hasNextPage': False}, 'status': [], 'datafiles': []}, 'result': [{'name':
#                     'Biomass',
#                      'uri': 'http://phenome.inrae.fr/id/variable/quality.biomass'}]}
#                     2026-07-21 15:47:16,036 — opensilex_python_client.variables._component_resolver — INFO —
#                     Component Characteristic exists: Biomass
#                     2026-07-21 15:47:16,038 — opensilex_python_client.variables.ctx — DEBUG —
#                     search_methods(name='Scale')
#                     2026-07-21 15:47:16,243 — opensilex_python_client.variables.ctx — DEBUG —   response:
#                     {'metadata': {'pagination': {'pageSize': 0, 'currentPage': 0, 'totalCount': 2, 'totalPages': 0,
#                     'limitCount': 0, 'hasNextPage': False}, 'status': [], 'datafiles': []}, 'result': [{'name':
#                     'Scale', 'uri': 'http://opensilex.test/id/variable/method.scale'}, {'name': 'Zadoks scale',
#                      'uri': 'http://phenome.inrae.fr/id/variable/method.zadoks-scale'}]}
#                     2026-07-21 15:47:16,245 — opensilex_python_client.variables._component_resolver — INFO —
#                     Component Method exists: Scale
#                     2026-07-21 15:47:16,247 — opensilex_python_client.variables.ctx — DEBUG —
#                     search_units(name='Kilogram')
#                     2026-07-21 15:47:16,476 — opensilex_python_client.variables.ctx — DEBUG —   response:
#                     {'metadata': {'pagination': {'pageSize': 0, 'currentPage': 0, 'totalCount': 7, 'totalPages': 0,
#                     'limitCount': 0, 'hasNextPage': False}, 'status': [], 'datafiles': []}, 'result': [{'name':
#                     'kilogram',
#                      'uri': 'http://www.ontology-of-units-of-measure.org/resource/om-2/kilogram'}, {'name':
#                     'kilogram per hectare',
#                      'uri': 'http://www.ontology-of-units-of-measure.org/resource/om-2/kilogramPerHectare'},
#                     {'name': 'metre kilogram',
#                      'uri': 'http://www.ontology-of-units-of-measure.org/resource/om-2/metreKilogram'}, {'name':
#                     'Kilogram', 'uri': 'http://opensilex.test/id/variable/unit.kilogram'}, {'name': 'Kilogram per
#                     Cubic Meter',
#                      'uri': 'http://purl.obolibrary.org/obo/NCIT_C42576'}, {'name': 'kilogram per cubic metre',
#                      'uri': 'http://www.ontology-of-units-of-measure.org/ressource/om-2/kilogramPerCubicmetre'},
#                     {'name': 'kilogram per square metre',
#                      'uri': 'http://www.ontology-of-units-of-measure.org/ressource/om-2/kilogramperSquareMetre'}]}
#                     2026-07-21 15:47:16,479 — opensilex_python_client.variables._component_resolver — INFO —
#                     Component Unit exists: Kilogram
#                     2026-07-21 15:47:16,480 — opensilex_python_client.variables.import_variables_from_csv — INFO —
#                     Starting variable creation step
# ================================================================================
# STEP 2: CREATING VARIABLES
# ================================================================================
#                     2026-07-21 15:47:16,482 — opensilex_python_client.variables.exists — INFO — Checking variable
#                     existence: name=Plant_Height_cm, uri=None
#                     2026-07-21 15:47:16,483 — opensilex_python_client.variables.ctx — DEBUG —
#                     search_variables(name='Plant_Height_cm')
#                     2026-07-21 15:47:16,627 — opensilex_python_client.variables.ctx — DEBUG —   response:
#                     {'metadata': {'pagination': {'pageSize': 20, 'currentPage': 0, 'totalCount': 17, 'totalPages':
#                     1, 'limitCount': 0, 'hasNextPage': True}, 'status': [], 'datafiles': []}, 'result':
#                     [{'alternative_name': 'PH_cm',
#                      'characteristic': {'name': 'Height',
#                                         'uri': 'http://purl.obolibrary.org/obo/PATO_0000119'},
#                      'data_type': 'xsd:decimal',
#                      'description': 'Plant height in centimeters',
#                      'entity': {'name': 'Plant',
#                                 'uri': 'opensilex-sandbox:id/variable/entity.plant'},
#                      'entity_of_interest': None,
#                      'method': {'name': 'Manual',
#                                 'uri': 'http://phenome.inrae.fr/id/variable/method.manual'},
#                      'name': 'Plant_Height_cm',
#                      'on_local': False,
#                      'shared_resource_instance': None,
#                      'unit': {'name': 'Centimeter',
#                               'uri': 'opensilex-sandbox:id/variable/unit.centimeter'},
#                      'uri': 'http://opensilex.test/id/variable/plant_height_cm'}, {'alternative_name': 'PH_cm',
#                      'characteristic': {'name': 'Height',
#                                         'uri': 'http://purl.obolibrary.org/obo/PATO_0000119'},
#                      'data_type': 'xsd:decimal',
#                      'description': 'Plant height in centimeters',
#                      'entity': {'name': 'Plant', 'uri': 'test-variable:Plant'},
#                      'entity_of_interest': None,
#                      'method': {'name': 'Manual',
#                                 'uri': 'http://phenome.inrae.fr/id/variable/method.manual'},
#                      'name': 'Plant_Height_cm',
#                      'on_local': False,
#                      'shared_resource_instance': None,
#                      'unit': {'name': 'Centimeter',
#                               'uri': 'opensilex-sandbox:id/variable/unit.centimeter'},
#                      'uri': 'http://opensilex.test/id/variable/plant_height_cm/1'}, {'alternative_name': 'PH_cm',
#                      'characteristic': {'name': 'Height',
#                                         'uri': 'http://purl.obolibrary.org/obo/PATO_0000119'},
#                      'data_type': 'xsd:decimal',
#                      'description': 'Plant height in centimeters',
#                      'entity': {'name': 'Plant', 'uri': 'test-variable:Plant'},
#                      'entity_of_interest': None,
#                      'method': {'name': 'Manual',
#                                 'uri': 'http://phenome.inrae.fr/id/variable/method.manual'},
#                      'name': 'Plant_Height_cm',
#                      'on_local': False,
#                      'shared_resource_instance': None,
#                      'unit': {'name': 'Centimeter',
#                               'uri': 'opensilex-sandbox:id/variable/unit.centimeter'},
#                      'uri': 'http://opensilex.test/id/variable/plant_height_cm/10'}, {'alternative_name': 'PH_cm',
#                      'characteristic': {'name': 'Height',
#                                         'uri': 'http://purl.obolibrary.org/obo/PATO_0000119'},
#                      'data_type': 'xsd:decimal',
#                      'description': 'Plant height in centimeters',
#                      'entity': {'name': 'Plant', 'uri': 'test-variable:Plant'},
#                      'entity_of_interest': None,
#                      'method': {'name': 'Manual',
#                                 'uri': 'http://phenome.inrae.fr/id/variable/method.manual'},
#                      'name': 'Plant_Height_cm',
#                      'on_local': False,
#                      'shared_resource_instance': None,
#                      'unit': {'name': 'Centimeter',
#                               'uri': 'opensilex-sandbox:id/variable/unit.centimeter'},
#                      'uri': 'http://opensilex.test/id/variable/plant_height_cm/11'}, {'alternative_name': 'PH_cm',
#                      'characteristic': {'name': 'Height',
#                                         'uri': 'http://purl.obolibrary.org/obo/PATO_0000119'},
#                      'data_type': 'xsd:decimal',
#                      'description': 'Plant height in centimeters',
#                      'entity': {'name': 'Plant', 'uri': 'test-variable:Plant'},
#                      'entity_of_interest': None,
#                      'method': {'name': 'Manual',
#                                 'uri': 'http://phenome.inrae.fr/id/variable/method.manual'},
#                      'name': 'Plant_Height_cm',
#                      'on_local': False,
#                      'shared_resource_instance': None,
#                      'unit': {'name': 'Centimeter',
#                               'uri': 'opensilex-sandbox:id/variable/unit.centimeter'},
#                      'uri': 'http://opensilex.test/id/variable/plant_height_cm/12'}, {'alternative_name': 'PH_cm',
#                      'characteristic': {'name': 'Height',
#                                         'uri': 'http://purl.obolibrary.org/obo/PATO_0000119'},
#                      'data_type': 'xsd:decimal',
#                      'description': 'Plant height in centimeters',
#                      'entity': {'name': 'Plant', 'uri': 'test-variable:Plant'},
#                      'entity_of_interest': None,
#                      'method': {'name': 'Manual',
#                                 'uri': 'http://phenome.inrae.fr/id/variable/method.manual'},
#                      'name': 'Plant_Height_cm',
#                      'on_local': False,
#                      'shared_resource_instance': None,
#                      'unit': {'name': 'Centimeter',
#                               'uri': 'opensilex-sandbox:id/variable/unit.centimeter'},
#                      'uri': 'http://opensilex.test/id/variable/plant_height_cm/13'}, {'alternative_name': 'PH_cm',
#                      'characteristic': {'name': 'Height',
#                                         'uri': 'http://purl.obolibrary.org/obo/PATO_0000119'},
#                      'data_type': 'xsd:decimal',
#                      'description': 'Plant height in centimeters',
#                      'entity': {'name': 'Plant', 'uri': 'test-variable:Plant'},
#                      'entity_of_interest': None,
#                      'method': {'name': 'Manual',
#                                 'uri': 'http://phenome.inrae.fr/id/variable/method.manual'},
#                      'name': 'Plant_Height_cm',
#                      'on_local': False,
#                      'shared_resource_instance': None,
#                      'unit': {'name': 'Centimeter',
#                               'uri': 'opensilex-sandbox:id/variable/unit.centimeter'},
#                      'uri': 'http://opensilex.test/id/variable/plant_height_cm/14'}, {'alternative_name': 'PH_cm',
#                      'characteristic': {'name': 'Height',
#                                         'uri': 'http://purl.obolibrary.org/obo/PATO_0000119'},
#                      'data_type': 'xsd:decimal',
#                      'description': 'Plant height in centimeters',
#                      'entity': {'name': 'Plant', 'uri': 'test-variable:Plant'},
#                      'entity_of_interest': None,
#                      'method': {'name': 'Manual',
#                                 'uri': 'http://phenome.inrae.fr/id/variable/method.manual'},
#                      'name': 'Plant_Height_cm',
#                      'on_local': False,
#                      'shared_resource_instance': None,
#                      'unit': {'name': 'Centimeter',
#                               'uri': 'opensilex-sandbox:id/variable/unit.centimeter'},
#                      'uri': 'http://opensilex.test/id/variable/plant_height_cm/2'}, {'alternative_name': 'PH_cm',
#                      'characteristic': {'name': 'Height',
#                                         'uri': 'http://purl.obolibrary.org/obo/PATO_0000119'},
#                      'data_type': 'xsd:decimal',
#                      'description': 'Plant height in centimeters',
#                      'entity': {'name': 'Plant', 'uri': 'test-variable:Plant'},
#                      'entity_of_interest': None,
#                      'method': {'name': 'Manual',
#                                 'uri': 'http://phenome.inrae.fr/id/variable/method.manual'},
#                      'name': 'Plant_Height_cm',
#                      'on_local': False,
#                      'shared_resource_instance': None,
#                      'unit': {'name': 'Centimeter',
#                               'uri': 'opensilex-sandbox:id/variable/unit.centimeter'},
#                      'uri': 'http://opensilex.test/id/variable/plant_height_cm/3'}, {'alternative_name': 'PH_cm',
#                      'characteristic': {'name': 'Height',
#                                         'uri': 'http://purl.obolibrary.org/obo/PATO_0000119'},
#                      'data_type': 'xsd:decimal',
#                      'description': 'Plant height in centimeters',
#                      'entity': {'name': 'Plant', 'uri': 'test-variable:Plant'},
#                      'entity_of_interest': None,
#                      'method': {'name': 'Manual',
#                                 'uri': 'http://phenome.inrae.fr/id/variable/method.manual'},
#                      'name': 'Plant_Height_cm',
#                      'on_local': False,
#                      'shared_resource_instance': None,
#                      'unit': {'name': 'Centimeter',
#                               'uri': 'opensilex-sandbox:id/variable/unit.centimeter'},
#                      'uri': 'http://opensilex.test/id/variable/plant_height_cm/4'}, {'alternative_name': 'PH_cm',
#                      'characteristic': {'name': 'Height',
#                                         'uri': 'http://purl.obolibrary.org/obo/PATO_0000119'},
#                      'data_type': 'xsd:decimal',
#                      'description': 'Plant height in centimeters',
#                      'entity': {'name': 'Plant', 'uri': 'test-variable:Plant'},
#                      'entity_of_interest': None,
#                      'method': {'name': 'Manual',
#                                 'uri': 'http://phenome.inrae.fr/id/variable/method.manual'},
#                      'name': 'Plant_Height_cm',
#                      'on_local': False,
#                      'shared_resource_instance': None,
#                      'unit': {'name': 'Centimeter',
#                               'uri': 'opensilex-sandbox:id/variable/unit.centimeter'},
#                      'uri': 'http://opensilex.test/id/variable/plant_height_cm/5'}, {'alternative_name': 'PH_cm',
#                      'characteristic': {'name': 'Height',
#                                         'uri': 'http://purl.obolibrary.org/obo/PATO_0000119'},
#                      'data_type': 'xsd:decimal',
#                      'description': 'Plant height in centimeters',
#                      'entity': {'name': 'Plant', 'uri': 'test-variable:Plant'},
#                      'entity_of_interest': None,
#                      'method': {'name': 'Manual',
#                                 'uri': 'http://phenome.inrae.fr/id/variable/method.manual'},
#                      'name': 'Plant_Height_cm',
#                      'on_local': False,
#                      'shared_resource_instance': None,
#                      'unit': {'name': 'Centimeter',
#                               'uri': 'opensilex-sandbox:id/variable/unit.centimeter'},
#                      'uri': 'http://opensilex.test/id/variable/plant_height_cm/6'}, {'alternative_name': 'PH_cm',
#                      'characteristic': {'name': 'Height',
#                                         'uri': 'http://purl.obolibrary.org/obo/PATO_0000119'},
#                      'data_type': 'xsd:decimal',
#                      'description': 'Plant height in centimeters',
#                      'entity': {'name': 'Plant', 'uri': 'test-variable:Plant'},
#                      'entity_of_interest': None,
#                      'method': {'name': 'Manual',
#                                 'uri': 'http://phenome.inrae.fr/id/variable/method.manual'},
#                      'name': 'Plant_Height_cm',
#                      'on_local': False,
#                      'shared_resource_instance': None,
#                      'unit': {'name': 'Centimeter',
#                               'uri': 'opensilex-sandbox:id/variable/unit.centimeter'},
#                      'uri': 'http://opensilex.test/id/variable/plant_height_cm/7'}, {'alternative_name': 'PH_cm',
#                      'characteristic': {'name': 'Height',
#                                         'uri': 'http://purl.obolibrary.org/obo/PATO_0000119'},
#                      'data_type': 'xsd:decimal',
#                      'description': 'Plant height in centimeters',
#                      'entity': {'name': 'Plant', 'uri': 'test-variable:Plant'},
#                      'entity_of_interest': None,
#                      'method': {'name': 'Manual',
#                                 'uri': 'http://phenome.inrae.fr/id/variable/method.manual'},
#                      'name': 'Plant_Height_cm',
#                      'on_local': False,
#                      'shared_resource_instance': None,
#                      'unit': {'name': 'Centimeter',
#                               'uri': 'opensilex-sandbox:id/variable/unit.centimeter'},
#                      'uri': 'http://opensilex.test/id/variable/plant_height_cm/8'}, {'alternative_name': 'PH_cm',
#                      'characteristic': {'name': 'Height',
#                                         'uri': 'http://purl.obolibrary.org/obo/PATO_0000119'},
#                      'data_type': 'xsd:decimal',
#                      'description': 'Plant height in centimeters',
#                      'entity': {'name': 'Plant', 'uri': 'test-variable:Plant'},
#                      'entity_of_interest': None,
#                      'method': {'name': 'Manual',
#                                 'uri': 'http://phenome.inrae.fr/id/variable/method.manual'},
#                      'name': 'Plant_Height_cm',
#                      'on_local': False,
#                      'shared_resource_instance': None,
#                      'unit': {'name': 'Centimeter',
#                               'uri': 'opensilex-sandbox:id/variable/unit.centimeter'},
#                      'uri': 'http://opensilex.test/id/variable/plant_height_cm/9'}, {'alternative_name': 'PH_cm',
#                      'characteristic': {'name': 'Height',
#                                         'uri': 'http://purl.obolibrary.org/obo/PATO_0000119'},
#                      'data_type': 'xsd:decimal',
#                      'description': 'Plant height in centimeters',
#                      'entity': {'name': 'Plant',
#                                 'uri': 'opensilex-sandbox:id/variable/entity.plant'},
#                      'entity_of_interest': None,
#                      'method': {'name': 'Manual',
#                                 'uri': 'http://phenome.inrae.fr/id/variable/method.manual'},
#                      'name': 'Plant_Height_cm_s',
#                      'on_local': False,
#                      'shared_resource_instance': None,
#                      'unit': {'name': 'Centimeter',
#                               'uri': 'opensilex-sandbox:id/variable/unit.centimeter'},
#                      'uri': 'http://opensilex.test/id/variable/plant_height_cm_s'}, {'alternative_name':
#                     'plant_Height_cm',
#                      'characteristic': {'name': 'Height',
#                                         'uri': 'http://purl.obolibrary.org/obo/PATO_0000119'},
#                      'data_type': 'xsd:decimal',
#                      'description': None,
#                      'entity': {'name': 'plant',
#                                 'uri': 'http://purl.obolibrary.org/obo/PO_0000003'},
#                      'entity_of_interest': None,
#                      'method': {'name': 'ImageProcessing',
#                                 'uri': 'opensilex-sandbox:id/variable/method.imageprocessing'},
#                      'name': 'plant_Height_ImageProcessing_centimetre',
#                      'on_local': False,
#                      'shared_resource_instance': None,
#                      'unit': {'name': 'centimetre',
#                               'uri': 'http://www.ontology-of-units-of-measure.org/resource/om-2/centimetre'},
#                      'uri': 'http://opensilex.test/id/variable/plant_height_imageprocessing_centimetre'}]}
#                     2026-07-21 15:47:16,640 — opensilex_python_client.variables.exists — INFO — Variable exists:
#                     Plant_Height_cm -> http://opensilex.test/id/variable/plant_height_cm
#                     2026-07-21 15:47:16,642 — opensilex_python_client.variables.exists — INFO — Checking variable
#                     existence: name=Plant_Biomass_kg, uri=None
#                     2026-07-21 15:47:16,643 — opensilex_python_client.variables.ctx — DEBUG —
#                     search_variables(name='Plant_Biomass_kg')
#                     2026-07-21 15:47:16,792 — opensilex_python_client.variables.ctx — DEBUG —   response:
#                     {'metadata': {'pagination': {'pageSize': 20, 'currentPage': 0, 'totalCount': 16, 'totalPages':
#                     1, 'limitCount': 0, 'hasNextPage': True}, 'status': [], 'datafiles': []}, 'result':
#                     [{'alternative_name': 'PB_kg',
#                      'characteristic': {'name': 'Biomass',
#                                         'uri': 'http://phenome.inrae.fr/id/variable/quality.biomass'},
#                      'data_type': 'xsd:decimal',
#                      'description': 'Plant biomass in kilograms',
#                      'entity': {'name': 'Plant',
#                                 'uri': 'opensilex-sandbox:id/variable/entity.plant'},
#                      'entity_of_interest': None,
#                      'method': {'name': 'Scale',
#                                 'uri': 'opensilex-sandbox:id/variable/method.scale'},
#                      'name': 'Plant_Biomass_kg',
#                      'on_local': False,
#                      'shared_resource_instance': None,
#                      'unit': {'name': 'Kilogram',
#                               'uri': 'opensilex-sandbox:id/variable/unit.kilogram'},
#                      'uri': 'http://opensilex.test/id/variable/plant_biomass_kg'}, {'alternative_name': 'PB_kg',
#                      'characteristic': {'name': 'Biomass',
#                                         'uri': 'http://phenome.inrae.fr/id/variable/quality.biomass'},
#                      'data_type': 'xsd:decimal',
#                      'description': 'Plant biomass in kilograms',
#                      'entity': {'name': 'Plant', 'uri': 'test-variable:Plant'},
#                      'entity_of_interest': None,
#                      'method': {'name': 'Scale',
#                                 'uri': 'opensilex-sandbox:id/variable/method.scale'},
#                      'name': 'Plant_Biomass_kg',
#                      'on_local': False,
#                      'shared_resource_instance': None,
#                      'unit': {'name': 'Kilogram',
#                               'uri': 'opensilex-sandbox:id/variable/unit.kilogram'},
#                      'uri': 'http://opensilex.test/id/variable/plant_biomass_kg/1'}, {'alternative_name': 'PB_kg',
#                      'characteristic': {'name': 'Biomass',
#                                         'uri': 'http://phenome.inrae.fr/id/variable/quality.biomass'},
# ...
#                      'shared_resource_instance': None,
#                      'unit': {'name': 'Kilogram',
#                               'uri': 'opensilex-sandbox:id/variable/unit.kilogram'},
#                      'uri': 'http://opensilex.test/id/variable/plant_biomass_kg/14'}, {'alternative_name': 'PB_kg',
#                      'characteristic': {'name': 'Biomass',
#                                         'uri': 'http://phenome.inrae.fr/id/variable/quality.biomass'},
#                      'data_type': 'xsd:decimal',
#                      'description': 'Plant biomass in kilograms',
#                      'entity': {'name': 'Plant', 'uri': 'test-variable:Plant'},
#                      'entity_of_interest': None,
#                      'method': {'name': 'Scale',
#                                 'uri': 'opensilex-sandbox:id/variable/method.scale'},
#                      'name': 'Plant_Biomass_kg',
#                      'on_local': False,
#                      'shared_resource_instance': None,
#                      'unit': {'name': 'Kilogram',
#                               'uri': 'opensilex-sandbox:id/variable/unit.kilogram'},
#                      'uri': 'http://opensilex.test/id/variable/plant_biomass_kg/2'}, {'alternative_name': 'PB_kg',
#                      'characteristic': {'name': 'Biomass',
#                                         'uri': 'http://phenome.inrae.fr/id/variable/quality.biomass'},
#                      'data_type': 'xsd:decimal',
#                      'description': 'Plant biomass in kilograms',
#                      'entity': {'name': 'Plant', 'uri': 'test-variable:Plant'},
#                      'entity_of_interest': None,
#                      'method': {'name': 'Scale',
#                                 'uri': 'opensilex-sandbox:id/variable/method.scale'},
#                      'name': 'Plant_Biomass_kg',
#                      'on_local': False,
#                      'shared_resource_instance': None,
#                      'unit': {'name': 'Kilogram',
#                               'uri': 'opensilex-sandbox:id/variable/unit.kilogram'},
#                      'uri': 'http://opensilex.test/id/variable/plant_biomass_kg/3'}, {'alternative_name': 'PB_kg',
#                      'characteristic': {'name': 'Biomass',
#                                         'uri': 'http://phenome.inrae.fr/id/variable/quality.biomass'},
#                      'data_type': 'xsd:decimal',
#                      'description': 'Plant biomass in kilograms',
#                      'entity': {'name': 'Plant', 'uri': 'test-variable:Plant'},
#                      'entity_of_interest': None,
#                      'method': {'name': 'Scale',
#                                 'uri': 'opensilex-sandbox:id/variable/method.scale'},
#                      'name': 'Plant_Biomass_kg',
#                      'on_local': False,
#                      'shared_resource_instance': None,
#                      'unit': {'name': 'Kilogram',
#                               'uri': 'opensilex-sandbox:id/variable/unit.kilogram'},
#                      'uri': 'http://opensilex.test/id/variable/plant_biomass_kg/4'}, {'alternative_name': 'PB_kg',
#                      'characteristic': {'name': 'Biomass',
#                                         'uri': 'http://phenome.inrae.fr/id/variable/quality.biomass'},
#                      'data_type': 'xsd:decimal',
#                      'description': 'Plant biomass in kilograms',
#                      'entity': {'name': 'Plant', 'uri': 'test-variable:Plant'},
#                      'entity_of_interest': None,
#                      'method': {'name': 'Scale',
#                                 'uri': 'opensilex-sandbox:id/variable/method.scale'},
#                      'name': 'Plant_Biomass_kg',
#                      'on_local': False,
#                      'shared_resource_instance': None,
#                      'unit': {'name': 'Kilogram',
#                               'uri': 'opensilex-sandbox:id/variable/unit.kilogram'},
#                      'uri': 'http://opensilex.test/id/variable/plant_biomass_kg/5'}, {'alternative_name': 'PB_kg',
#                      'characteristic': {'name': 'Biomass',
#                                         'uri': 'http://phenome.inrae.fr/id/variable/quality.biomass'},
#                      'data_type': 'xsd:decimal',
#                      'description': 'Plant biomass in kilograms',
#                      'entity': {'name': 'Plant', 'uri': 'test-variable:Plant'},
#                      'entity_of_interest': None,
#                      'method': {'name': 'Scale',
#                                 'uri': 'opensilex-sandbox:id/variable/method.scale'},
#                      'name': 'Plant_Biomass_kg',
#                      'on_local': False,
#                      'shared_resource_instance': None,
#                      'unit': {'name': 'Kilogram',
#                               'uri': 'opensilex-sandbox:id/variable/unit.kilogram'},
#                      'uri': 'http://opensilex.test/id/variable/plant_biomass_kg/6'}, {'alternative_name': 'PB_kg',
#                      'characteristic': {'name': 'Biomass',
#                                         'uri': 'http://phenome.inrae.fr/id/variable/quality.biomass'},
#                      'data_type': 'xsd:decimal',
#                      'description': 'Plant biomass in kilograms',
#                      'entity': {'name': 'Plant', 'uri': 'test-variable:Plant'},
#                      'entity_of_interest': None,
#                      'method': {'name': 'Scale',
#                                 'uri': 'opensilex-sandbox:id/variable/method.scale'},
#                      'name': 'Plant_Biomass_kg',
#                      'on_local': False,
#                      'shared_resource_instance': None,
#                      'unit': {'name': 'Kilogram',
#                               'uri': 'opensilex-sandbox:id/variable/unit.kilogram'},
#                      'uri': 'http://opensilex.test/id/variable/plant_biomass_kg/7'}, {'alternative_name': 'PB_kg',
#                      'characteristic': {'name': 'Biomass',
#                                         'uri': 'http://phenome.inrae.fr/id/variable/quality.biomass'},
#                      'data_type': 'xsd:decimal',
#                      'description': 'Plant biomass in kilograms',
#                      'entity': {'name': 'Plant', 'uri': 'test-variable:Plant'},
#                      'entity_of_interest': None,
#                      'method': {'name': 'Scale',
#                                 'uri': 'opensilex-sandbox:id/variable/method.scale'},
#                      'name': 'Plant_Biomass_kg',
#                      'on_local': False,
#                      'shared_resource_instance': None,
#                      'unit': {'name': 'Kilogram',
#                               'uri': 'opensilex-sandbox:id/variable/unit.kilogram'},
#                      'uri': 'http://opensilex.test/id/variable/plant_biomass_kg/8'}, {'alternative_name': 'PB_kg',
#                      'characteristic': {'name': 'Biomass',
#                                         'uri': 'http://phenome.inrae.fr/id/variable/quality.biomass'},
#                      'data_type': 'xsd:decimal',
#                      'description': 'Plant biomass in kilograms',
#                      'entity': {'name': 'Plant', 'uri': 'test-variable:Plant'},
#                      'entity_of_interest': None,
#                      'method': {'name': 'Scale',
#                                 'uri': 'opensilex-sandbox:id/variable/method.scale'},
#                      'name': 'Plant_Biomass_kg',
#                      'on_local': False,
#                      'shared_resource_instance': None,
#                      'unit': {'name': 'Kilogram',
#                               'uri': 'opensilex-sandbox:id/variable/unit.kilogram'},
#                      'uri': 'http://opensilex.test/id/variable/plant_biomass_kg/9'}, {'alternative_name': 'PB_kg',
#                      'characteristic': {'name': 'Biomass',
#                                         'uri': 'http://phenome.inrae.fr/id/variable/quality.biomass'},
#                      'data_type': 'xsd:decimal',
#                      'description': 'Plant biomass in kilograms',
#                      'entity': {'name': 'Plant',
#                                 'uri': 'opensilex-sandbox:id/variable/entity.plant'},
#                      'entity_of_interest': None,
#                      'method': {'name': 'Scale',
#                                 'uri': 'opensilex-sandbox:id/variable/method.scale'},
#                      'name': 'Plant_Biomass_kg_s',
#                      'on_local': False,
#                      'shared_resource_instance': None,
#                      'unit': {'name': 'Kilogram',
#                               'uri': 'opensilex-sandbox:id/variable/unit.kilogram'},
#                      'uri': 'http://opensilex.test/id/variable/plant_biomass_kg_s'}]}
#                     2026-07-21 15:47:16,803 — opensilex_python_client.variables.exists — INFO — Variable exists:
#                     Plant_Biomass_kg -> http://opensilex.test/id/variable/plant_biomass_kg
#                     2026-07-21 15:47:16,804 — opensilex_python_client.variables.import_variables_from_csv — INFO —
#                     Variable creation summary: created=0, existing=2, failed=0
#                     2026-07-21 15:47:16,808 — opensilex_python_client.variables.import_variables_from_csv — INFO —
#                     Enriched CSV saved:
#                     /home/charleroy/GIT/GITLAB/opensilex_python_client/notebooks/data_examples/variables/test_varia
#                     bles_with_uris_enriched.csv

# %%
# 4. Attach to groups
config = read_yaml(input_config_path)
group_config = config.get("groups", {})
available_groups = group_config.get("available_groups", {})

for group_name, group_uri in available_groups.items():
    group=  manage.find_or_create_group(client, group_uri if group_uri else None, group_name, debug=True)
    print(f"Existing {group }" )
# Out:
#                     2026-07-21 15:47:16,821 — opensilex_python_client.variables.groups.manage — DEBUG —
#                     get_variables_group(uri='http://opensilex.test/id/variablesGroup/example')
#                     2026-07-21 15:47:16,919 — opensilex_python_client.variables.groups.manage — DEBUG —   response:
#                     {'metadata': {'pagination': {'pageSize': 0, 'currentPage': 0, 'totalCount': 0, 'totalPages': 0,
#                     'limitCount': 0, 'hasNextPage': False}, 'status': [], 'datafiles': []}, 'result':
#                     {'description': '',
#                      'last_updated_date': datetime.datetime(2026, 7, 21, 10, 21, 46, 603801, tzinfo=tzutc()),
#                      'name': 'example',
#                      'publication_date': datetime.datetime(2026, 7, 20, 22, 13, 0, 581162, tzinfo=tzutc()),
#                      'publisher': {'admin': True,
#                                    'email': 'guest@opensilex.org',
#                                    'enable': True,
#                                    'favorites': None,
#                                    'first_name': 'Guest',
#                                    'language': 'en',
#                                    'last_name': 'OpenSILEX',
#                                    'linked_person': 'opensilex-sandbox:id/user/guest.opensilex/Person',
#                                    'uri': 'opensilex-sandbox:id/user/guest.opensilex'},
#                      'uri': 'opensilex-sandbox:id/variablesGroup/example',
#                      'variables': [{'last_updated_date': None,
#                                     'name': 'Plant_Biomass_kg',
#                                     'publication_date': None,
#                                     'rdf_type': 'vocabulary:Variable',
#                                     'rdf_type_name': 'Variable',
#                                     'uri': 'opensilex-sandbox:id/variable/plant_biomass_kg/14'},
#                                    {'last_updated_date': None,
#                                     'name': 'Plant_Height_cm',
#                                     'publication_date': None,
#                                     'rdf_type': 'vocabulary:Variable',
#                                     'rdf_type_name': 'Variable',
#                                     'uri': 'opensilex-sandbox:id/variable/plant_height_cm'},
#                                    {'last_updated_date': None,
#                                     'name': 'Plant_Height_cm',
#                                     'publication_date': None,
#                                     'rdf_type': 'vocabulary:Variable',
#                                     'rdf_type_name': 'Variable',
#                                     'uri': 'opensilex-sandbox:id/variable/plant_height_cm/14'},
#                                    {'last_updated_date': None,
#                                     'name': 'Plant_Biomass_kg',
#                                     'publication_date': None,
#                                     'rdf_type': 'vocabulary:Variable',
#                                     'rdf_type_name': 'Variable',
#                                     'uri': 'opensilex-sandbox:id/variable/plant_biomass_kg'}]}}
# Existing opensilex-sandbox:id/variablesGroup/example

# %%
# 5. Attach to groups
manage.attach_variables(client, grouped_vars, input_config_path)

# %%
print(" Import completed!")
