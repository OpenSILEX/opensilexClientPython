# %% [markdown]
# # Example script for importing variables into OpenSILEX.

# %%
import json
import os

from opensilex_python_client.auth import connect
from opensilex_python_client.file_management.read_yaml import read_yaml
from opensilex_python_client.variables import download_config_example, import_from_csv
from opensilex_python_client.variables.groups import manage

# %%
# 1. Authentication
with open('credentials.json') as f:
    credentials_dict = json.load(f)

client = connect.connect_to_opensilex(
    credentials_dict
)
# Out:
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ✓ Successful connection

# %% [markdown]
# ## Generate files to upload

# %%
# 2. File paths (modify these paths)
save_file_path = os.path.join(os.path.abspath(""), "output_files")
os.makedirs(save_file_path, exist_ok=True)
data_examples_variables_dir_path = os.path.realpath(os.path.join(os.path.abspath(""), "../data_examples/variables"))
os.makedirs(data_examples_variables_dir_path, exist_ok=True)
print(f"Config files: {data_examples_variables_dir_path}")

download_config_example.download_variables_config(data_examples_variables_dir_path)
# Out:
# Config files: /home/charleroy/GIT/GITLAB/opensilex_python_client/notebooks/data_examples/variables
# ✅ Saved test_variables.csv to /home/charleroy/GIT/GITLAB/opensilex_python_client/notebooks/data_examples/variables/test_variables.csv
# ✅ Saved test_config.yaml to /home/charleroy/GIT/GITLAB/opensilex_python_client/notebooks/data_examples/variables/test_config.yaml
# ✅ Saved test_variables_with_uris.csv to /home/charleroy/GIT/GITLAB/opensilex_python_client/notebooks/data_examples/variables/test_variables_with_uris.csv
#
# ✅ All 3 files saved to /home/charleroy/GIT/GITLAB/opensilex_python_client/notebooks/data_examples/variables

# %%
## 3. load files 


# without uris
# input_csv_path = os.path.realpath(os.path.join(os.path.abspath(""), "../data_examples/variables", "test_variables.csv"))
# with uris
input_csv_path = os.path.realpath(os.path.join(os.path.abspath(""), "../data_examples/variables", "test_variables_with_uris.csv"))

input_config_path = os.path.realpath(
    os.path.join(os.path.abspath(""), "../data_examples/variables", "test_config.yaml")
)
print(f"Input CSV path: {os.path.realpath(input_csv_path)}")
print(f"Input Config path: {os.path.realpath(input_config_path)}")
# Out:
# Input CSV path: /home/charleroy/GIT/GITLAB/opensilex_python_client/notebooks/data_examples/variables/test_variables_with_uris.csv
# Input Config path: /home/charleroy/GIT/GITLAB/opensilex_python_client/notebooks/data_examples/variables/test_config.yaml

# %%
# 3. Import variables (creates components + variables automatically)
grouped_vars = import_from_csv.run(client, input_csv_path, input_config_path, True)
# Out:
# 📄 Loading CSV and configuration...
# ✓ Loaded 2 rows from CSV
# 🔍 Resolving column mappings...
#   ✓ Mapped 16 columns
# ================================================================================
# STEP 1: CREATING COMPONENTS (AUTO-GENERATION FROM NAMES)
# ================================================================================
#   [DEBUG] get_entity(uri='test-variable:Plant')
#   [DEBUG]   response: {'metadata': {'pagination': {'pageSize': 0, 'currentPage': 0, 'totalCount': 0, 'totalPages': 0, 'limitCount': 0, 'hasNextPage': False}, 'status': [], 'datafiles': []}, 'result': {'broad_match': [],
#  'close_match': [],
#  'description': 'Plant organism',
#  'exact_match': [],
#  'from_shared_resource_instance': None,
#  'last_updated_date': None,
#  'name': 'Plant',
#  'narrow_match': [],
#  'publication_date': datetime.datetime(2026, 7, 20, 13, 59, 31, 594784, tzinfo=tzutc()),
#  'publisher': {'admin': True,
#                'email': 'guest@opensilex.org',
#                'enable': True,
#                'favorites': None,
#                'first_name': 'Guest',
#                'language': 'en',
#                'last_name': 'OpenSILEX',
#                'linked_person': 'opensilex-sandbox:id/user/guest.opensilex/Person',
#                'uri': 'opensilex-sandbox:id/user/guest.opensilex'},
#  'uri': 'test-variable:Plant'}}
#   ✓ Entity exists (by URI): test-variable:Plant
# Final_Entity_URI: test-variable:Plant
#   [DEBUG] search_characteristics(name='Height')
#   [DEBUG]   response: {'metadata': {'pagination': {'pageSize': 0, 'currentPage': 0, 'totalCount': 5, 'totalPages': 0, 'limitCount': 0, 'hasNextPage': False}, 'status': [], 'datafiles': []}, 'result': [{'name': 'height',
#  'uri': 'http://phenome.inrae.fr/id/variable/characteristic.height'}, {'name': 'Height', 'uri': 'http://purl.obolibrary.org/obo/PATO_0000119'}, {'name': 'HeightFlag',
#  'uri': 'http://phenome.inrae.fr/id/variable/quality.heightflag'}, {'name': 'HeightStd',
#  'uri': 'http://phenome.inrae.fr/id/variable/quality.heightstd'}, {'name': 'Mean plant height',
#  'uri': 'http://phenome.inrae.fr/id/variable/characteristic.mean_plant_height'}]}
#   ✓ Characteristic exists: Height
# Final_Characteristic_URI: http://purl.obolibrary.org/obo/PATO_0000119
#   [DEBUG] search_methods(name='Manual')
#   [DEBUG]   response: {'metadata': {'pagination': {'pageSize': 0, 'currentPage': 0, 'totalCount': 1, 'totalPages': 0, 'limitCount': 0, 'hasNextPage': False}, 'status': [], 'datafiles': []}, 'result': [{'name': 'Manual', 'uri': 'http://phenome.inrae.fr/id/variable/method.manual'}]}
#   ✓ Method exists: Manual
# Final_Method_URI: http://phenome.inrae.fr/id/variable/method.manual
#   [DEBUG] search_units(name='Centimeter')
#   [DEBUG]   response: {'metadata': {'pagination': {'pageSize': 0, 'currentPage': 0, 'totalCount': 1, 'totalPages': 0, 'limitCount': 0, 'hasNextPage': False}, 'status': [], 'datafiles': []}, 'result': [{'name': 'Centimeter',
#  'uri': 'http://opensilex.test/id/variable/unit.centimeter'}]}
#   ✓ Unit exists: Centimeter
# Final_Unit_URI: http://opensilex.test/id/variable/unit.centimeter
#   [DEBUG] get_entity(uri='test-variable:Plant')
#   [DEBUG]   response: {'metadata': {'pagination': {'pageSize': 0, 'currentPage': 0, 'totalCount': 0, 'totalPages': 0, 'limitCount': 0, 'hasNextPage': False}, 'status': [], 'datafiles': []}, 'result': {'broad_match': [],
#  'close_match': [],
#  'description': 'Plant organism',
#  'exact_match': [],
#  'from_shared_resource_instance': None,
#  'last_updated_date': None,
#  'name': 'Plant',
#  'narrow_match': [],
#  'publication_date': datetime.datetime(2026, 7, 20, 13, 59, 31, 594784, tzinfo=tzutc()),
#  'publisher': {'admin': True,
#                'email': 'guest@opensilex.org',
#                'enable': True,
#                'favorites': None,
#                'first_name': 'Guest',
#                'language': 'en',
#                'last_name': 'OpenSILEX',
#                'linked_person': 'opensilex-sandbox:id/user/guest.opensilex/Person',
#                'uri': 'opensilex-sandbox:id/user/guest.opensilex'},
#  'uri': 'test-variable:Plant'}}
#   ✓ Entity exists (by URI): test-variable:Plant
# Final_Entity_URI: test-variable:Plant
#   [DEBUG] search_characteristics(name='Biomass')
#   [DEBUG]   response: {'metadata': {'pagination': {'pageSize': 0, 'currentPage': 0, 'totalCount': 1, 'totalPages': 0, 'limitCount': 0, 'hasNextPage': False}, 'status': [], 'datafiles': []}, 'result': [{'name': 'Biomass',
#  'uri': 'http://phenome.inrae.fr/id/variable/quality.biomass'}]}
#   ✓ Characteristic exists: Biomass
# Final_Characteristic_URI: http://phenome.inrae.fr/id/variable/quality.biomass
#   [DEBUG] search_methods(name='Scale')
#   [DEBUG]   response: {'metadata': {'pagination': {'pageSize': 0, 'currentPage': 0, 'totalCount': 2, 'totalPages': 0, 'limitCount': 0, 'hasNextPage': False}, 'status': [], 'datafiles': []}, 'result': [{'name': 'Scale', 'uri': 'http://opensilex.test/id/variable/method.scale'}, {'name': 'Zadoks scale',
#  'uri': 'http://phenome.inrae.fr/id/variable/method.zadoks-scale'}]}
#   ✓ Method exists: Scale
# Final_Method_URI: http://opensilex.test/id/variable/method.scale
#   [DEBUG] search_units(name='Kilogram')
#   [DEBUG]   response: {'metadata': {'pagination': {'pageSize': 0, 'currentPage': 0, 'totalCount': 7, 'totalPages': 0, 'limitCount': 0, 'hasNextPage': False}, 'status': [], 'datafiles': []}, 'result': [{'name': 'kilogram',
#  'uri': 'http://www.ontology-of-units-of-measure.org/resource/om-2/kilogram'}, {'name': 'kilogram per hectare',
#  'uri': 'http://www.ontology-of-units-of-measure.org/resource/om-2/kilogramPerHectare'}, {'name': 'metre kilogram',
#  'uri': 'http://www.ontology-of-units-of-measure.org/resource/om-2/metreKilogram'}, {'name': 'Kilogram', 'uri': 'http://opensilex.test/id/variable/unit.kilogram'}, {'name': 'Kilogram per Cubic Meter',
#  'uri': 'http://purl.obolibrary.org/obo/NCIT_C42576'}, {'name': 'kilogram per cubic metre',
#  'uri': 'http://www.ontology-of-units-of-measure.org/ressource/om-2/kilogramPerCubicmetre'}, {'name': 'kilogram per square metre',
#  'uri': 'http://www.ontology-of-units-of-measure.org/ressource/om-2/kilogramperSquareMetre'}]}
#   ✓ Unit exists: Kilogram
# Final_Unit_URI: http://opensilex.test/id/variable/unit.kilogram
# ================================================================================
# STEP 2: CREATING VARIABLES
# ================================================================================
# ['Plant_Height_cm', 'test-variable:Plant', 'http://purl.obolibrary.org/obo/PATO_0000119', 'http://phenome.inrae.fr/id/variable/method.manual', 'http://opensilex.test/id/variable/unit.centimeter', 'http://www.w3.org/2001/XMLSchema#decimal']
#   ✗ Error searching variable: 'OntologyApi' object has no attribute 'get_namespace'
#   [DEBUG] create_variable(name='Plant_Height_cm', entity='test-variable:Plant')
#   [DEBUG]   response: {'metadata': {'pagination': {'pageSize': 0, 'currentPage': 0, 'totalCount': 0, 'totalPages': 0, 'limitCount': 0, 'hasNextPage': False}, 'status': [], 'datafiles': ['opensilex-sandbox:id/variable/plant_height_cm/12']}, 'result': ['opensilex-sandbox:id/variable/plant_height_cm/12']}
#   ✓ Variable created: Plant_Height_cm → opensilex-sandbox:id/variable/plant_height_cm/12
# ['Plant_Biomass_kg', 'test-variable:Plant', 'http://phenome.inrae.fr/id/variable/quality.biomass', 'http://opensilex.test/id/variable/method.scale', 'http://opensilex.test/id/variable/unit.kilogram', 'http://www.w3.org/2001/XMLSchema#decimal']
#   ✗ Error searching variable: 'OntologyApi' object has no attribute 'get_namespace'
#   [DEBUG] create_variable(name='Plant_Biomass_kg', entity='test-variable:Plant')
#   [DEBUG]   response: {'metadata': {'pagination': {'pageSize': 0, 'currentPage': 0, 'totalCount': 0, 'totalPages': 0, 'limitCount': 0, 'hasNextPage': False}, 'status': [], 'datafiles': ['opensilex-sandbox:id/variable/plant_biomass_kg/12']}, 'result': ['opensilex-sandbox:id/variable/plant_biomass_kg/12']}
#   ✓ Variable created: Plant_Biomass_kg → opensilex-sandbox:id/variable/plant_biomass_kg/12
# Traceback (most recent call last):
#   File "/home/charleroy/GIT/GITLAB/opensilex_python_client/src/opensilex_python_client/variables/exists.py", line 25, in exists_variable_ctx
#     namespace = ontology_api.get_namespace()
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^^
# AttributeError: 'OntologyApi' object has no attribute 'get_namespace'. Did you mean: 'get_name_space'?
# Traceback (most recent call last):
#   File "/home/charleroy/GIT/GITLAB/opensilex_python_client/src/opensilex_python_client/variables/exists.py", line 25, in exists_variable_ctx
#     namespace = ontology_api.get_namespace()
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^^
# AttributeError: 'OntologyApi' object has no attribute 'get_namespace'. Did you mean: 'get_name_space'?
# 📊 STEP 2 SUMMARY:
#    Created: 2, Existing: 0, Failed: 0
# ✓ Enriched CSV saved:
# /home/charleroy/GIT/GITLAB/opensilex_python_client/notebooks/data_examples/variables/test_variables_with_uris_enric
# hed.csv

# %%
# 4. Attach to groups
config = read_yaml(input_config_path)
group_config = config.get("groups", {})
available_groups = group_config.get("available_groups", {})

for group_name, group_uri in available_groups.items():
    group=  manage.find_or_create_group(client, group_uri if group_uri else None, group_name, debug=True)
    print(f"Existing {group }" )
# Out:
#   [DEBUG] get_variables_group(uri='http://opensilex.test/id/variablesGroup/example')
#   [DEBUG]   response: {'metadata': {'pagination': {'pageSize': 0, 'currentPage': 0, 'totalCount': 0, 'totalPages': 0, 'limitCount': 0, 'hasNextPage': False}, 'status': [], 'datafiles': []}, 'result': {'description': '',
#  'last_updated_date': datetime.datetime(2026, 7, 20, 22, 29, 54, 206855, tzinfo=tzutc()),
#  'name': 'example',
#  'publication_date': datetime.datetime(2026, 7, 20, 22, 13, 0, 581162, tzinfo=tzutc()),
#  'publisher': {'admin': True,
#                'email': 'guest@opensilex.org',
#                'enable': True,
#                'favorites': None,
#                'first_name': 'Guest',
#                'language': 'en',
#                'last_name': 'OpenSILEX',
#                'linked_person': 'opensilex-sandbox:id/user/guest.opensilex/Person',
#                'uri': 'opensilex-sandbox:id/user/guest.opensilex'},
#  'uri': 'opensilex-sandbox:id/variablesGroup/example',
#  'variables': [{'last_updated_date': None,
#                 'name': 'Plant_Height_cm',
#                 'publication_date': None,
#                 'rdf_type': 'vocabulary:Variable',
#                 'rdf_type_name': 'Variable',
#                 'uri': 'opensilex-sandbox:id/variable/plant_height_cm'},
#                {'last_updated_date': None,
#                 'name': 'Plant_Biomass_kg',
#                 'publication_date': None,
#                 'rdf_type': 'vocabulary:Variable',
#                 'rdf_type_name': 'Variable',
#                 'uri': 'opensilex-sandbox:id/variable/plant_biomass_kg'}]}}
# Existing opensilex-sandbox:id/variablesGroup/example

# %%
# 5. Attach to groups
manage.attach_variables(client, grouped_vars, input_config_path)
# Out:
# ================================================================================
# STEP 3: ATTACHING TO GROUPS
# ================================================================================
# http://opensilex.test/ in opensilex-sandbox:id/variable/plant_height_cm/12
# http://opensilex.test/ in opensilex-sandbox:id/variable/plant_biomass_kg/12
#   ✗ Error updating group http://opensilex.test/id/variablesGroup/example: 'VariablesGroupGetDTO' object has no attribute 'get'
#
# ✅ STEP 3 COMPLETE

# %%
print(" Import completed!")
